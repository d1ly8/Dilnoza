# %% [markdown]
# <a href="https://colab.research.google.com/github/d1ly8/Dilnoza/blob/main/example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Please update the information, and submit your work

# %%
my_name = "Dilnoza"

# %%
my_enrollment_number = "A85204925039"

# %%
my_hobby = "hiking"

# %%
print("Hello, my name is {}, and my my enrollment number is {}. I like {}.".format(my_name, my_enrollment_number, my_hobby))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1776/3738604305.py in <cell line: 0>()
# ----> 1 print("Hello, my name is {}, and my my enrollment number is {}. I like {}.".format(my_name, my_enrollment_number, my_hobby))
#
# NameError: name 'my_name' is not defined
